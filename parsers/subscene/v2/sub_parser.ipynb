# %%
import pysrt
import sys
import numpy as np
import string
import os
import datetime
import collections
from tqdm import tqdm

# %%
def is_overlap(ival_a, ival_b):
    start_a, end_a = ival_a
    start_b, end_b = ival_b
    return (start_a <= start_b <= end_a) or (start_b <= start_a <= end_b)


def overlap_size(ival_a, ival_b):
    assert is_overlap(ival_a, ival_b), 'no overlap!'
    start_a, end_a = ival_a
    start_b, end_b = ival_b
    return min(end_a, end_b) - max(start_a, start_b)


def score_and_match(ja_ts_map, en_ts_map):
    """ match up two {(ts): caption} mappings and score them
    
        each match is of the form:
        {
            ja_ival: {
                ja_caption: "...",
                en_matches: [
                    {
                        ival: en_ival,
                        caption: "...",
                        overlap: ...
                    }
                ]
            } 
        }
    """
    ja_matches = 0
    matches = {}
    for ja_ival, ja_caption in ja_ts_map.items():
        matches[ja_ival] = {
            'ja_caption': ja_caption,
            'en_matches': []
        }

        caption_match = False
        for en_ival, en_caption in en_ts_map.items():
            if is_overlap(ja_ival, en_ival):
                matches[ja_ival]['en_matches'].append({
                    'ival': en_ival,
                    'caption': en_caption,
                    'overlap': overlap_size(en_ival, ja_ival)
                })
                caption_match = True
        ja_matches = ja_matches + (1 if caption_match else 0)

    return ja_matches * 1.0 / len(ja_ts_map), matches


def ts_caption_mapping(f):
    """ produce {(interval): caption} mapping for a file
    """
    def sub_ival(sub):
        pivot = datetime.date(2017, 01, 01)
        return datetime.datetime.combine(pivot, sub.start.to_time()), \
               datetime.datetime.combine(pivot, sub.end.to_time())
    
    subs = pysrt.open(f)
    out = {}
    for sub in subs:
        out[sub_ival(sub)] = sub.text_without_tags
    return out


def gather_mappings(lang_dir):
    """ produce {subfile: {(interval): caption}} mappings for a directory
    """
    out = {}
    for subfile in os.listdir(lang_dir):
        out[subfile] = ts_caption_mapping(os.path.join(lang_dir, subfile))
    return out


def extract_subs_for_title(title_dir, coverage_threshold):
    """ parse and align subs for a title
    
        precondition:
            title_dir/
                en/
                    en .srt files
                ja/
                    ja .srt files
    """
    print 'STARTING ', title_dir
    
    print '\t PARSING .srt FILES...'
    ja_sub_mappings = gather_mappings(os.path.join(title_dir, 'ja'))
    en_sub_mappings = gather_mappings(os.path.join(title_dir, 'en'))
    
    print '\t ALIGNING SUBS...'
    match_candidates = []
    for (ja_title, ja_subs) in ja_sub_mappings.items():
        for (en_title, en_subs) in en_sub_mappings.items():
            coverage, matches = score_and_match(ja_subs, en_subs)
            match_candidates.append( (
                coverage,
                matches,
                os.path.join(title_dir, 'ja', ja_title),
                os.path.join(title_dir, 'en', en_title),
            ) )
    match_candidates = sorted(match_candidates)[::-1]

    print '\t EXTRACTING BEST MATCHES...'
    out = {}
    i = 0
    while match_candidates[i][0] > coverage_threshold:
        print '\t\t working on file ', i
        coverage, matches, ja_path, en_path = match_candidates[i]
        for ja_ival, match in matches.items():
            ja_caption = match['ja_caption']
            
            if len(match['en_matches']) == 0: continue
            
            en_captions = sorted(match['en_matches'], key=lambda x: x['overlap'])[::-1]
            # TODO - take best, not first?
            if not ja_ival in out:
                out[ja_ival] = {
                    'ja': ja_caption,
                    'en': en_captions[0]['caption'],
                    'overlap': en_captions[0]['overlap']
                 }
        i += 1
    return out

# %%
root = 'out'

os.system("find %s -type f -name '*.DS_Store' -delete" % root)

SUBS = {title: {} for title in os.listdir(root)}

coverage_threshold = 0.85

for title in os.listdir(root):
    SUBS[title] = extract_subs_for_title(os.path.join(root, title), coverage_threshold)
    
for title, ts_caption_mapping in SUBS.items():
    for ts, caption in ts_caption_mapping.items():
#        print caption
        print caption['ja']
        print caption['en']
        print
# Out:
# [{'caption': u'Hamilton, you know too much.', 'ival': (datetime.datetime(2017, 1, 1, 0, 10, 27, 210000), datetime.datetime(2017, 1, 1, 0, 10, 29, 429000)), 'overlap': datetime.timedelta(0, 2, 219000)}]
# ハミルトン、知っているだろ
# {'caption': u'Hamilton, you know too much.', 'ival': (datetime.datetime(2017, 1, 1, 0, 10, 27, 210000), datetime.datetime(2017, 1, 1, 0, 10, 29, 429000)), 'overlap': datetime.timedelta(0, 2, 219000)}
# {'caption': u'Hamilton, you know too much.', 'ival': (datetime.datetime(2017, 1, 1, 0, 10, 27, 210000), datetime.datetime(2017, 1, 1, 0, 10, 29, 429000)), 'overlap': datetime.timedelta(0, 2, 219000)}
#
# [{'caption': u"You must know that I'm not a slave.", 'ival': (datetime.datetime(2017, 1, 1, 0, 53, 35, 87000), datetime.datetime(2017, 1, 1, 0, 53, 37, 840000)), 'overlap': datetime.timedelta(0, 2, 753000)}]
# 私は奴隷ではありません
# {'caption': u"You must know that I'm not a slave.", 'ival': (datetime.datetime(2017, 1, 1, 0, 53, 35, 87000), datetime.datetime(2017, 1, 1, 0, 53, 37, 840000)), 'overlap': datetime.timedelta(0, 2, 753000)}
# {'caption': u"You must know that I'm not a slave.", 'ival': (datetime.datetime(2017, 1, 1, 0, 53, 35, 87000), datetime.datetime(2017, 1, 1, 0, 53, 37, 840000)), 'overlap': datetime.timedelta(0, 2, 753000)}
#
# [{'caption': u'MR. MOON: Devil call his\nname, there he is now.', 'ival': (datetime.datetime(2017, 1, 1, 0, 8, 47, 318000), datetime.datetime(2017, 1, 1, 0, 8, 48, 945000)), 'overlap': datetime.timedelta(0, 1, 627000)}]
# 噂をすれば 来たぞ
# {'caption': u'MR. MOON: Devil call his\nname, there he is now.', 'ival': (datetime.datetime(2017, 1, 1, 0, 8, 47, 318000), datetime.datetime(2017, 1, 1, 0, 8, 48, 945000)), 'overlap': datetime.timedelta(0, 1, 627000)}
# {'caption': u'MR. MOON: Devil call his\nname, there he is now.', 'ival': (datetime.datetime(2017, 1, 1, 0, 8, 47, 318000), datetime.datetime(2017, 1, 1, 0, 8, 48, 945000)), 'overlap': datetime.timedelta(0, 1, 627000)}
#
# [{'caption': u'You menfolk got no shame\nletting Patsey out-pick you.', 'ival': (datetime.datetime(2017, 1, 1, 0, 56, 42, 399000), datetime.datetime(2017, 1, 1, 0, 56, 46, 404000)), 'overlap': datetime.timedelta(0, 4, 5000)}]
# 野郎どもはパッツイに負けて
# 恥ずかしくないか？
# {'caption': u'You menfolk got no shame\nletting Patsey out-pick you.', 'ival': (datetime.datetime(2017, 1, 1, 0, 56, 42, 399000), datetime.datetime(2017, 1, 1, 0, 56, 46, 404000)), 'overlap': datetime.timedelta(0, 4, 5000)}
# {'caption': u'You menfolk got no shame\nletting Patsey out-pick you.', 'ival': (datetime.datetime(2017, 1, 1, 0, 56, 42, 399000), datetime.datetime(2017, 1, 1, 0, 56, 46, 404000)), 'overlap': datetime.timedelta(0, 4, 5000)}
#
# [{'caption': u'My Lord', 'ival': (datetime.datetime(2017, 1, 1, 0, 2, 18, 472000), datetime.datetime(2017, 1, 1, 0, 2, 19, 815000)), 'overlap': datetime.timedelta(0, 1, 343000)}]
#
# {'caption': u'My Lord', 'ival': (datetime.datetime(2017, 1, 1, 0, 2, 18, 472000), datetime.datetime(2017, 1, 1, 0, 2, 19, 815000)), 'overlap': datetime.timedelta(0, 1, 343000)}
# {'caption': u'My Lord', 'ival': (datetime.datetime(2017, 1, 1, 0, 2, 18, 472000), datetime.datetime(2017, 1, 1, 0, 2, 19, 815000)), 'overlap': datetime.timedelta(0, 1, 343000)}
#
# [{'caption': u'(THUNDER RUMBLING)', 'ival': (datetime.datetime(2017, 1, 1, 1, 18, 36, 503000), datetime.datetime(2017, 1, 1, 1, 18, 38, 130000)), 'overlap': datetime.timedelta(0, 1, 627000)}]
#
# {'caption': u'(THUNDER RUMBLING)', 'ival': (datetime.datetime(2017, 1, 1, 1, 18, 36, 503000), datetime.datetime(2017, 1, 1, 1, 18, 38, 130000)), 'overlap': datetime.timedelta(0, 1, 627000)}
# {'caption': u'(THUNDER RUMBLING)', 'ival': (datetime.datetime(2017, 1, 1, 1, 18, 36, 503000), datetime.datetime(2017, 1, 1, 1, 18, 38, 130000)), 'overlap': datetime.timedelta(0, 1, 627000)}
#
# [{'caption': u'(INDISTINCT CONVERSATIONS)', 'ival': (datetime.datetime(2017, 1, 1, 0, 26, 11, 403000), datetime.datetime(2017, 1, 1, 0, 26, 13, 326000)), 'overlap': datetime.timedelta(0, 1, 923000)}]
#
# {'caption': u'(INDISTINCT CONVERSATIONS)', 'ival': (datetime.datetime(2017, 1, 1, 0, 26, 11, 403000), datetime.datetime(2017, 1, 1, 0, 26, 13, 326000)), 'overlap': datetime.timedelta(0, 1, 923000)}
# {'caption': u'(INDISTINCT CONVERSATIONS)', 'ival': (datetime.datetime(2017, 1, 1, 0, 26, 11, 403000), datetime.datetime(2017, 1, 1, 0, 26, 13, 326000)), 'overlap': datetime.timedelta(0, 1, 923000)}
#
# [{'caption': u'My Lord', 'ival': (datetime.datetime(2017, 1, 1, 0, 1, 43, 604000), datetime.datetime(2017, 1, 1, 0, 1, 44, 696000)), 'overlap': datetime.timedelta(0, 1, 92000)}]
#
# {'caption': u'My Lord', 'ival': (datetime.datetime(2017, 1, 1, 0, 1, 43, 604000), datetime.datetime(2017, 1, 1, 0, 1, 44, 696000)), 'overlap': datetime.timedelta(0, 1, 92000)}
# {'caption': u'My Lord', 'ival': (datetime.datetime(2017, 1, 1, 0, 1, 43, 604000), datetime.datetime(2017, 1, 1, 0, 1, 44, 696000)), 'overlap': datetime.timedelta(0, 1, 92000)}
#
# [{'caption': u'Get your fiddle, Platt.\nGet up!', 'ival': (datetime.datetime(2017, 1, 1, 0, 59, 56, 802000), datetime.datetime(2017, 1, 1, 0, 59, 58, 304000)), 'overlap': datetime.timedelta(0, 1, 502000)}]
# プラットはバイオリンだ
# {'caption': u'Get your fiddle, Platt.\nGet up!', 'ival': (datetime.datetime(2017, 1, 1, 0, 59, 56, 802000), datetime.datetime(2017, 1, 1, 0, 59, 58, 304000)), 'overlap': datetime.timedelta(0, 1, 502000)}
# {'caption': u'Get your fiddle, Platt.\nGet up!', 'ival': (datetime.datetime(2017, 1, 1, 0, 59, 56, 802000), datetime.datetime(2017, 1, 1, 0, 59, 58, 304000)), 'overlap': datetime.timedelta(0, 1, 502000)}
#
# [{'caption': u"You don't.", 'ival': (datetime.datetime(2017, 1, 1, 0, 8, 10, 73000), datetime.datetime(2017, 1, 1, 0, 8, 11, 996000)), 'overlap': datetime.timedelta(0, 1, 923000)}]
# そうよ
# {'caption': u"You don't.", 'ival': (datetime.datetime(2017, 1, 1, 0, 8, 10, 73000), datetime.datetime(2017, 1, 1, 0, 8, 11, 996000)), 'overlap': datetime.timedelta(0, 1, 923000)}
# {'caption': u"You don't.", 'ival': (datetime.datetime(2017, 1, 1, 0, 8, 10, 73000), datetime.datetime(2017, 1, 1, 0, 8, 11, 996000)), 'overlap': datetime.timedelta(0, 1, 923000)}
#
# [{'caption': u'WOMAN: (SINGING)\nSun gonna set here', 'ival': (datetime.datetime(2017, 1, 1, 1, 38, 14, 180000), datetime.datetime(2017, 1, 1, 1, 38, 16, 274000)), 'overlap': datetime.timedelta(0, 2, 94000)}]
# Sun gonna set here
# {'caption': u'WOMAN: (SINGING)\nSun gonna set here', 'ival': (datetime.datetime(2017, 1, 1, 1, 38, 14, 180000), datetime.datetime(2017, 1, 1, 1, 38, 16, 274000)), 'overlap': datetime.timedelta(0, 2, 94000)}
# {'caption': u'WOMAN: (SINGING)\nSun gonna set here', 'ival': (datetime.datetime(2017, 1, 1, 1, 38, 14, 180000), datetime.datetime(2017, 1, 1, 1, 38, 16, 274000)), 'overlap': datetime.timedelta(0, 2, 94000)}
#
# [{'caption': u'If you want to survive, do and\nsay as little as possible.', 'ival': (datetime.datetime(2017, 1, 1, 0, 21, 35, 127000), datetime.datetime(2017, 1, 1, 0, 21, 39, 428000)), 'overlap': datetime.timedelta(0, 4, 301000)}]
# 生き残りたけりゃ
# 口を閉じとけよ
# {'caption': u'If you want to survive, do and\nsay as little as possible.', 'ival': (datetime.datetime(2017, 1, 1, 0, 21, 35, 127000), datetime.datetime(2017, 1, 1, 0, 21, 39, 428000)), 'overlap': datetime.timedelta(0, 4, 301000)}
# {'caption': u'If you want to survive, do and\nsay as little as possible.', 'ival': (datetime.datetime(2017, 1, 1, 0, 21, 35, 127000), datetime.datetime(2017, 1, 1, 0, 21, 39, 428000)), 'overlap': datetime.timedelta(0, 4, 301000)}
#
# [{'caption': u"I don't say that to give\nyou empty agitation, John.", 'ival': (datetime.datetime(2017, 1, 1, 0, 18, 47, 877000), datetime.datetime(2017, 1, 1, 0, 18, 49, 877000)), 'overlap': datetime.timedelta(0, 2)}]
# 気休めを言うわけじゃないが ジョン...
# {'caption': u"I don't say that to give\nyou empty agitation, John.", 'ival': (datetime.datetime(2017, 1, 1, 0, 18, 47, 877000), datetime.datetime(2017, 1, 1, 0, 18, 49, 877000)), 'overlap': datetime.timedelta(0, 2)}
# {'caption': u"I don't say that to give\nyou empty agitation, John.", 'ival': (datetime.datetime(2017, 1, 1, 0, 18, 47, 877000), datetime.datetime(2017, 1, 1, 0, 18, 49, 877000)), 'overlap': datetime.timedelta(0, 2)}
#
# [{'caption': u"You can't remain the Sabbath\nwithout her under your eye?", 'ival': (datetime.datetime(2017, 1, 1, 1, 12, 9, 200000), datetime.datetime(2017, 1, 1, 1, 12, 12, 44000)), 'overlap': datetime.timedelta(0, 2, 844000)}]
# 安息日にもかかわらず
# 女ばかりに目をつけて
# {'caption': u"You can't remain the Sabbath\nwithout her under your eye?", 'ival': (datetime.datetime(2017, 1, 1, 1, 12, 9, 200000), datetime.datetime(2017, 1, 1, 1, 12, 12, 44000)), 'overlap': datetime.timedelta(0, 2, 844000)}
# {'caption': u"You can't remain the Sabbath\nwithout her under your eye?", 'ival': (datetime.datetime(2017, 1, 1, 1, 12, 9, 200000), datetime.datetime(2017, 1, 1, 1, 12, 12, 44000)), 'overlap': datetime.timedelta(0, 2, 844000)}
#
# [{'caption': u'They are, sir.', 'ival': (datetime.datetime(2017, 1, 1, 0, 42, 35, 219000), datetime.datetime(2017, 1, 1, 0, 42, 36, 141000)), 'overlap': datetime.timedelta(0, 0, 922000)}]
# きれいですよ
# {'caption': u'They are, sir.', 'ival': (datetime.datetime(2017, 1, 1, 0, 42, 35, 219000), datetime.datetime(2017, 1, 1, 0, 42, 36, 141000)), 'overlap': datetime.timedelta(0, 0, 922000)}
# {'caption': u'They are, sir.', 'ival': (datetime.datetime(2017, 1, 1, 0, 42, 35, 219000), datetime.datetime(2017, 1, 1, 0, 42, 36, 141000)), 'overlap': datetime.timedelta(0, 0, 922000)}
#
# [{'caption': u"Where's the boy called Platt?", 'ival': (datetime.datetime(2017, 1, 1, 2, 0, 53, 663000), datetime.datetime(2017, 1, 1, 2, 0, 55, 711000)), 'overlap': datetime.timedelta(0, 2, 48000)}]
# プラットという男はいるか？
# {'caption': u"Where's the boy called Platt?", 'ival': (datetime.datetime(2017, 1, 1, 2, 0, 53, 663000), datetime.datetime(2017, 1, 1, 2, 0, 55, 711000)), 'overlap': datetime.timedelta(0, 2, 48000)}
# {'caption': u"Where's the boy called Platt?", 'ival': (datetime.datetime(2017, 1, 1, 2, 0, 53, 663000), datetime.datetime(2017, 1, 1, 2, 0, 55, 711000)), 'overlap': datetime.timedelta(0, 2, 48000)}
#
# [{'caption': u"Let's go!", 'ival': (datetime.datetime(2017, 1, 1, 0, 20, 20, 136000), datetime.datetime(2017, 1, 1, 0, 20, 21, 479000)), 'overlap': datetime.timedelta(0, 1, 343000)}]
# 行くぞ！
# {'caption': u"Let's go!", 'ival': (datetime.datetime(2017, 1, 1, 0, 20, 20, 136000), datetime.datetime(2017, 1, 1, 0, 20, 21, 479000)), 'overlap': datetime.timedelta(0, 1, 343000)}
# {'caption': u"Let's go!", 'ival': (datetime.datetime(2017, 1, 1, 0, 20, 20, 136000), datetime.datetime(2017, 1, 1, 0, 20, 21, 479000)), 'overlap': datetime.timedelta(0, 1, 343000)}
#
# [{'caption': u'Sit and drink\nthe tea that I offered.', 'ival': (datetime.datetime(2017, 1, 1, 1, 7, 36, 594000), datetime.datetime(2017, 1, 1, 1, 7, 38, 642000)), 'overlap': datetime.timedelta(0, 2, 48000)}]
# 座ってお茶を飲みなさい
# {'caption': u'Sit and drink\nthe tea that I offered.', 'ival': (datetime.datetime(2017, 1, 1, 1, 7, 36, 594000), datetime.datetime(2017, 1, 1, 1, 7, 38, 642000)), 'overlap': datetime.timedelta(0, 2, 48000)}
# {'caption': u'Sit and drink\nthe tea that I offered.', 'ival': (datetime.datetime(2017, 1, 1, 1, 7, 36, 594000), datetime.datetime(2017, 1, 1, 1, 7, 38, 642000)), 'overlap': datetime.timedelta(0, 2, 48000)}
#
# [{'caption': u'Come on.', 'ival': (datetime.datetime(2017, 1, 1, 0, 20, 42, 324000), datetime.datetime(2017, 1, 1, 0, 20, 43, 166000)), 'overlap': datetime.timedelta(0, 0, 842000)}]
# 来い
# {'caption': u'Come on.', 'ival': (datetime.datetime(2017, 1, 1, 0, 20, 42, 324000), datetime.datetime(2017, 1, 1, 0, 20, 43, 166000)), 'overlap': datetime.timedelta(0, 0, 842000)}
# {'caption': u'Come on.', 'ival': (datetime.datetime(2017, 1, 1, 0, 20, 42, 324000), datetime.datetime(2017, 1, 1, 0, 20, 43, 166000)), 'overlap': datetime.timedelta(0, 0, 842000)}
#
# [{'caption': u'Collect a team. See\nwhat good you can do.', 'ival': (datetime.datetime(2017, 1, 1, 0, 37, 24, 534000), datetime.datetime(2017, 1, 1, 0, 37, 26, 582000)), 'overlap': datetime.timedelta(0, 2, 48000)}]
# チームを作って
# やってみてくれ
# {'caption': u'Collect a team. See\nwhat good you can do.', 'ival': (datetime.datetime(2017, 1, 1, 0, 37, 24, 534000), datetime.datetime(2017, 1, 1, 0, 37, 26, 582000)), 'overlap': datetime.timedelta(0, 2, 48000)}
# {'caption': u'Collect a team. See\nwhat good you can do.', 'ival': (datetime.datetime(2017, 1, 1, 0, 37, 24, 534000), datetime.datetime(2017, 1, 1, 0, 37, 26, 582000)), 'overlap': datetime.timedelta(0, 2, 48000)}
#
# [{'caption': u"It's official business.", 'ival': (datetime.datetime(2017, 1, 1, 2, 2, 7, 904000), datetime.datetime(2017, 1, 1, 2, 2, 9, 281000)), 'overlap': datetime.timedelta(0, 1, 377000)}]
# これは公務だ
# {'caption': u"It's official business.", 'ival': (datetime.datetime(2017, 1, 1, 2, 2, 7, 904000), datetime.datetime(2017, 1, 1, 2, 2, 9, 281000)), 'overlap': datetime.timedelta(0, 1, 377000)}
# {'caption': u"It's official business.", 'ival': (datetime.datetime(2017, 1, 1, 2, 2, 7, 904000), datetime.datetime(2017, 1, 1, 2, 2, 9, 281000)), 'overlap': datetime.timedelta(0, 1, 377000)}
#
# [{'caption': u'Where John baptized three', 'ival': (datetime.datetime(2017, 1, 1, 1, 39, 55, 114000), datetime.datetime(2017, 1, 1, 1, 39, 58, 288000)), 'overlap': datetime.timedelta(0, 3, 174000)}]
# Where John baptized three
# {'caption': u'Where John baptized three', 'ival': (datetime.datetime(2017, 1, 1, 1, 39, 55, 114000), datetime.datetime(2017, 1, 1, 1, 39, 58, 288000)), 'overlap': datetime.timedelta(0, 3, 174000)}
# {'caption': u'Where John baptized three', 'ival': (datetime.datetime(2017, 1, 1, 1, 39, 55, 114000), datetime.datetime(2017, 1, 1, 1, 39, 58, 288000)), 'overlap': datetime.timedelta(0, 3, 174000)}
#
# [{'caption': u'(SINGING) Went down to\nthe River Jordan', 'ival': (datetime.datetime(2017, 1, 1, 1, 39, 51, 569000), datetime.datetime(2017, 1, 1, 1, 39, 54, 948000)), 'overlap': datetime.timedelta(0, 3, 379000)}]
# Went down to
# the River Jordan
# {'caption': u'(SINGING) Went down to\nthe River Jordan', 'ival': (datetime.datetime(2017, 1, 1, 1, 39, 51, 569000), datetime.datetime(2017, 1, 1, 1, 39, 54, 948000)), 'overlap': datetime.timedelta(0, 3, 379000)}
# {'caption': u'(SINGING) Went down to\nthe River Jordan', 'ival': (datetime.datetime(2017, 1, 1, 1, 39, 51, 569000), datetime.datetime(2017, 1, 1, 1, 39, 54, 948000)), 'overlap': datetime.timedelta(0, 3, 379000)}
#
# [{'caption': u'(LAUGHING)', 'ival': (datetime.datetime(2017, 1, 1, 1, 11, 19, 692000), datetime.datetime(2017, 1, 1, 1, 11, 21, 114000)), 'overlap': datetime.timedelta(0, 1, 422000)}]
#
# {'caption': u'(LAUGHING)', 'ival': (datetime.datetime(2017, 1, 1, 1, 11, 19, 692000), datetime.datetime(2017, 1, 1, 1, 11, 21, 114000)), 'overlap': datetime.timedelta(0, 1, 422000)}
# {'caption': u'(LAUGHING)', 'ival': (datetime.datetime(2017, 1, 1, 1, 11, 19, 692000), datetime.datetime(2017, 1, 1, 1, 11, 21, 114000)), 'overlap': datetime.timedelta(0, 1, 422000)}
#
# [{'caption': u'(PANTING)', 'ival': (datetime.datetime(2017, 1, 1, 1, 6, 43, 750000), datetime.datetime(2017, 1, 1, 1, 6, 45, 252000)), 'overlap': datetime.timedelta(0, 1, 502000)}]
#
# {'caption': u'(PANTING)', 'ival': (datetime.datetime(2017, 1, 1, 1, 6, 43, 750000), datetime.datetime(2017, 1, 1, 1, 6, 45, 252000)), 'overlap': datetime.timedelta(0, 1, 502000)}
# {'caption': u'(PANTING)', 'ival': (datetime.datetime(2017, 1, 1, 1, 6, 43, 750000), datetime.datetime(2017, 1, 1, 1, 6, 45, 252000)), 'overlap': datetime.timedelta(0, 1, 502000)}
#
# [{'caption': u"Y'all gonna be in a cutting gang.", 'ival': (datetime.datetime(2017, 1, 1, 0, 1, 12, 698000), datetime.datetime(2017, 1, 1, 0, 1, 14, 245000)), 'overlap': datetime.timedelta(0, 1, 547000)}]
# 刈り方の手本だ
# {'caption': u"Y'all gonna be in a cutting gang.", 'ival': (datetime.datetime(2017, 1, 1, 0, 1, 12, 698000), datetime.datetime(2017, 1, 1, 0, 1, 14, 245000)), 'overlap': datetime.timedelta(0, 1, 547000)}
# {'caption': u"Y'all gonna be in a cutting gang.", 'ival': (datetime.datetime(2017, 1, 1, 0, 1, 12, 698000), datetime.datetime(2017, 1, 1, 0, 1, 14, 245000)), 'overlap': datetime.timedelta(0, 1, 547000)}
#
# [{'caption': u'(SCREAMING)', 'ival': (datetime.datetime(2017, 1, 1, 0, 46, 34, 875000), datetime.datetime(2017, 1, 1, 0, 46, 36, 377000)), 'overlap': datetime.timedelta(0, 1, 502000)}]
#
# {'caption': u'(SCREAMING)', 'ival': (datetime.datetime(2017, 1, 1, 0, 46, 34, 875000), datetime.datetime(2017, 1, 1, 0, 46, 36, 377000)), 'overlap': datetime.timedelta(0, 1, 502000)}
# {'caption': u'(SCREAMING)', 'ival': (datetime.datetime(2017, 1, 1, 0, 46, 34, 875000), datetime.datetime(2017, 1, 1, 0, 46, 36, 377000)), 'overlap': datetime.timedelta(0, 1, 502000)}
#
# [{'caption': u'Any more will earn you 100 lashes.', 'ival': (datetime.datetime(2017, 1, 1, 1, 3, 17, 460000), datetime.datetime(2017, 1, 1, 1, 3, 20, 134000)), 'overlap': datetime.timedelta(0, 2, 674000)}]
# そしてそれ以外は
# 100の鞭打ち
# {'caption': u'Any more will earn you 100 lashes.', 'ival': (datetime.datetime(2017, 1, 1, 1, 3, 17, 460000), datetime.datetime(2017, 1, 1, 1, 3, 20, 134000)), 'overlap': datetime.timedelta(0, 2, 674000)}
# {'caption': u'Any more will earn you 100 lashes.', 'ival': (datetime.datetime(2017, 1, 1, 1, 3, 17, 460000), datetime.datetime(2017, 1, 1, 1, 3, 20, 134000)), 'overlap': datetime.timedelta(0, 2, 674000)}
#
# [{'caption': u"That's my girl.\nDon't ever let me down.", 'ival': (datetime.datetime(2017, 1, 1, 1, 28, 52, 953000), datetime.datetime(2017, 1, 1, 1, 28, 55, 752000)), 'overlap': datetime.timedelta(0, 2, 799000)}]
# 俺の女だ
# 裏切らない
# {'caption': u"That's my girl.\nDon't ever let me down.", 'ival': (datetime.datetime(2017, 1, 1, 1, 28, 52, 953000), datetime.datetime(2017, 1, 1, 1, 28, 55, 752000)), 'overlap': datetime.timedelta(0, 2, 799000)}
# {'caption': u"That's my girl.\nDon't ever let me down.", 'ival': (datetime.datetime(2017, 1, 1, 1, 28, 52, 953000), datetime.datetime(2017, 1, 1, 1, 28, 55, 752000)), 'overlap': datetime.timedelta(0, 2, 799000)}
#
# [{'caption': u'Anne Hampton.\nI am who I say.', 'ival': (datetime.datetime(2017, 1, 1, 2, 2, 19, 916000), datetime.datetime(2017, 1, 1, 2, 2, 21, 418000)), 'overlap': datetime.timedelta(0, 1, 502000)}]
# アン・ハンプトン
# 私自身です
# {'caption': u'Anne Hampton.\nI am who I say.', 'ival': (datetime.datetime(2017, 1, 1, 2, 2, 19, 916000), datetime.datetime(2017, 1, 1, 2, 2, 21, 418000)), 'overlap': datetime.timedelta(0, 1, 502000)}
# {'caption': u'Anne Hampton.\nI am who I say.', 'ival': (datetime.datetime(2017, 1, 1, 2, 2, 19, 916000), datetime.datetime(2017, 1, 1, 2, 2, 21, 418000)), 'overlap': datetime.timedelta(0, 1, 502000)}
#
# [{'caption': u'Rags and tatters.', 'ival': (datetime.datetime(2017, 1, 1, 0, 17, 25, 461000), datetime.datetime(2017, 1, 1, 0, 17, 27, 884000)), 'overlap': datetime.timedelta(0, 2, 423000)}]
# ボロ雑巾
# {'caption': u'Rags and tatters.', 'ival': (datetime.datetime(2017, 1, 1, 0, 17, 25, 461000), datetime.datetime(2017, 1, 1, 0, 17, 27, 884000)), 'overlap': datetime.timedelta(0, 2, 423000)}
# {'caption': u'Rags and tatters.', 'ival': (datetime.datetime(2017, 1, 1, 0, 17, 25, 461000), datetime.datetime(2017, 1, 1, 0, 17, 27, 884000)), 'overlap': datetime.timedelta(0, 2, 423000)}
#
# [{'caption': u'Run, nigger, run\nWell, you better get away', 'ival': (datetime.datetime(2017, 1, 1, 0, 34, 24, 479000), datetime.datetime(2017, 1, 1, 0, 34, 26, 652000)), 'overlap': datetime.timedelta(0, 2, 173000)}]
# 走れ二ガー
# 全速力で逃げるんだ
# {'caption': u'Run, nigger, run\nWell, you better get away', 'ival': (datetime.datetime(2017, 1, 1, 0, 34, 24, 479000), datetime.datetime(2017, 1, 1, 0, 34, 26, 652000)), 'overlap': datetime.timedelta(0, 2, 173000)}
# {'caption': u'Run, nigger, run\nWell, you better get away', 'ival': (datetime.datetime(2017, 1, 1, 0, 34, 24, 479000), datetime.datetime(2017, 1, 1, 0, 34, 26, 652000)), 'overlap': datetime.timedelta(0, 2, 173000)}
#
# [{'caption': u'We know nothing of her, Master.', 'ival': (datetime.datetime(2017, 1, 1, 1, 45, 50, 219000), datetime.datetime(2017, 1, 1, 1, 45, 51, 459000)), 'overlap': datetime.timedelta(0, 1, 240000)}]
# わかりません、旦那様
# {'caption': u'We know nothing of her, Master.', 'ival': (datetime.datetime(2017, 1, 1, 1, 45, 50, 219000), datetime.datetime(2017, 1, 1, 1, 45, 51, 459000)), 'overlap': datetime.timedelta(0, 1, 240000)}
# {'caption': u'We know nothing of her, Master.', 'ival': (datetime.datetime(2017, 1, 1, 1, 45, 50, 219000), datetime.datetime(2017, 1, 1, 1, 45, 51, 459000)), 'overlap': datetime.timedelta(0, 1, 240000)}
#
# [{'caption': u'Your story...', 'ival': (datetime.datetime(2017, 1, 1, 1, 56, 8, 211000), datetime.datetime(2017, 1, 1, 1, 56, 9, 884000)), 'overlap': datetime.timedelta(0, 1, 673000)}]
# キミの話は...
# {'caption': u'Your story...', 'ival': (datetime.datetime(2017, 1, 1, 1, 56, 8, 211000), datetime.datetime(2017, 1, 1, 1, 56, 9, 884000)), 'overlap': datetime.timedelta(0, 1, 673000)}
# {'caption': u'Your story...', 'ival': (datetime.datetime(2017, 1, 1, 1, 56, 8, 211000), datetime.datetime(2017, 1, 1, 1, 56, 9, 884000)), 'overlap': datetime.timedelta(0, 1, 673000)}
#
# [{'caption': u'Willard Yarner,\na planter up the bayou...', 'ival': (datetime.datetime(2017, 1, 1, 1, 24, 24, 810000), datetime.datetime(2017, 1, 1, 1, 24, 26, 983000)), 'overlap': datetime.timedelta(0, 2, 173000)}]
# 上流農家の
# ウィラード・ヤーナー...
# {'caption': u'Willard Yarner,\na planter up the bayou...', 'ival': (datetime.datetime(2017, 1, 1, 1, 24, 24, 810000), datetime.datetime(2017, 1, 1, 1, 24, 26, 983000)), 'overlap': datetime.timedelta(0, 2, 173000)}
# {'caption': u'Willard Yarner,\na planter up the bayou...', 'ival': (datetime.datetime(2017, 1, 1, 1, 24, 24, 810000), datetime.datetime(2017, 1, 1, 1, 24, 26, 983000)), 'overlap': datetime.timedelta(0, 2, 173000)}
#
# [{'caption': u'verifying the negro known as\nClemens Ray is my property.', 'ival': (datetime.datetime(2017, 1, 1, 0, 25, 15, 180000), datetime.datetime(2017, 1, 1, 0, 25, 17, 933000)), 'overlap': datetime.timedelta(0, 2, 753000)}]
# クレメンズ・レイは
# 私が所有している
# {'caption': u'verifying the negro known as\nClemens Ray is my property.', 'ival': (datetime.datetime(2017, 1, 1, 0, 25, 15, 180000), datetime.datetime(2017, 1, 1, 0, 25, 17, 933000)), 'overlap': datetime.timedelta(0, 2, 753000)}
# {'caption': u'verifying the negro known as\nClemens Ray is my property.', 'ival': (datetime.datetime(2017, 1, 1, 0, 25, 15, 180000), datetime.datetime(2017, 1, 1, 0, 25, 17, 933000)), 'overlap': datetime.timedelta(0, 2, 753000)}
#
# [{'caption': u'Such is the pity.', 'ival': (datetime.datetime(2017, 1, 1, 0, 12, 55, 608000), datetime.datetime(2017, 1, 1, 0, 12, 56, 951000)), 'overlap': datetime.timedelta(0, 1, 343000)}]
# 哀れだな
# {'caption': u'Such is the pity.', 'ival': (datetime.datetime(2017, 1, 1, 0, 12, 55, 608000), datetime.datetime(2017, 1, 1, 0, 12, 56, 951000)), 'overlap': datetime.timedelta(0, 1, 343000)}
# {'caption': u'Such is the pity.', 'ival': (datetime.datetime(2017, 1, 1, 0, 12, 55, 608000), datetime.datetime(2017, 1, 1, 0, 12, 56, 951000)), 'overlap': datetime.timedelta(0, 1, 343000)}
#
# [{'caption': u'Follow your mama.', 'ival': (datetime.datetime(2017, 1, 1, 0, 20, 11, 544000), datetime.datetime(2017, 1, 1, 0, 20, 13, 46000)), 'overlap': datetime.timedelta(0, 1, 502000)}]
# ママに着いてけ
# {'caption': u'Follow your mama.', 'ival': (datetime.datetime(2017, 1, 1, 0, 20, 11, 544000), datetime.datetime(2017, 1, 1, 0, 20, 13, 46000)), 'overlap': datetime.timedelta(0, 1, 502000)}
# {'caption': u'Follow your mama.', 'ival': (datetime.datetime(2017, 1, 1, 0, 20, 11, 544000), datetime.datetime(2017, 1, 1, 0, 20, 13, 46000)), 'overlap': datetime.timedelta(0, 1, 502000)}
#
# [{'caption': u'But I beg you not to expose me\nif you cannot grant the request.', 'ival': (datetime.datetime(2017, 1, 1, 1, 31, 58, 96000), datetime.datetime(2017, 1, 1, 1, 32, 2, 146000)), 'overlap': datetime.timedelta(0, 4, 50000)}]
# だが無理なら
# 暴露しないでくれ
# {'caption': u'But I beg you not to expose me\nif you cannot grant the request.', 'ival': (datetime.datetime(2017, 1, 1, 1, 31, 58, 96000), datetime.datetime(2017, 1, 1, 1, 32, 2, 146000)), 'overlap': datetime.timedelta(0, 4, 50000)}
# {'caption': u'But I beg you not to expose me\nif you cannot grant the request.', 'ival': (datetime.datetime(2017, 1, 1, 1, 31, 58, 96000), datetime.datetime(2017, 1, 1, 1, 32, 2, 146000)), 'overlap': datetime.timedelta(0, 4, 50000)}
#
# [{'caption': u'Yes, Mistress.', 'ival': (datetime.datetime(2017, 1, 1, 1, 2, 43, 677000), datetime.datetime(2017, 1, 1, 1, 2, 44, 678000)), 'overlap': datetime.timedelta(0, 1, 1000)}]
# はい奥様
# {'caption': u'Yes, Mistress.', 'ival': (datetime.datetime(2017, 1, 1, 1, 2, 43, 677000), datetime.datetime(2017, 1, 1, 1, 2, 44, 678000)), 'overlap': datetime.timedelta(0, 1, 1000)}
# {'caption': u'Yes, Mistress.', 'ival': (datetime.datetime(2017, 1, 1, 1, 2, 43, 677000), datetime.datetime(2017, 1, 1, 1, 2, 44, 678000)), 'overlap': datetime.timedelta(0, 1, 1000)}
#
# [{'caption': u'Courthouse got papers to prove it!', 'ival': (datetime.datetime(2017, 1, 1, 2, 2, 59, 581000), datetime.datetime(2017, 1, 1, 2, 3, 0, 958000)), 'overlap': datetime.timedelta(0, 1, 377000)}]
# 裁判所に証明書がある
# {'caption': u'Courthouse got papers to prove it!', 'ival': (datetime.datetime(2017, 1, 1, 2, 2, 59, 581000), datetime.datetime(2017, 1, 1, 2, 3, 0, 958000)), 'overlap': datetime.timedelta(0, 1, 377000)}
# {'caption': u'Courthouse got papers to prove it!', 'ival': (datetime.datetime(2017, 1, 1, 2, 2, 59, 581000), datetime.datetime(2017, 1, 1, 2, 3, 0, 958000)), 'overlap': datetime.timedelta(0, 1, 377000)}
#
# [{'caption': u'We have much acquainting to do.', 'ival': (datetime.datetime(2017, 1, 1, 2, 6, 24, 452000), datetime.datetime(2017, 1, 1, 2, 6, 26, 671000)), 'overlap': datetime.timedelta(0, 2, 219000)}]
# 沢山話す事がありそうだ
# {'caption': u'We have much acquainting to do.', 'ival': (datetime.datetime(2017, 1, 1, 2, 6, 24, 452000), datetime.datetime(2017, 1, 1, 2, 6, 26, 671000)), 'overlap': datetime.timedelta(0, 2, 219000)}
# {'caption': u'We have much acquainting to do.', 'ival': (datetime.datetime(2017, 1, 1, 2, 6, 24, 452000), datetime.datetime(2017, 1, 1, 2, 6, 26, 671000)), 'overlap': datetime.timedelta(0, 2, 219000)}
#
# [{'caption': u'(GASPING)', 'ival': (datetime.datetime(2017, 1, 1, 0, 5, 3, 261000), datetime.datetime(2017, 1, 1, 0, 5, 4, 513000)), 'overlap': datetime.timedelta(0, 1, 252000)}]
#
# {'caption': u'(GASPING)', 'ival': (datetime.datetime(2017, 1, 1, 0, 5, 3, 261000), datetime.datetime(2017, 1, 1, 0, 5, 4, 513000)), 'overlap': datetime.timedelta(0, 1, 252000)}
# {'caption': u'(GASPING)', 'ival': (datetime.datetime(2017, 1, 1, 0, 5, 3, 261000), datetime.datetime(2017, 1, 1, 0, 5, 4, 513000)), 'overlap': datetime.timedelta(0, 1, 252000)}
#
# [{'caption': u'(GRUNTS)', 'ival': (datetime.datetime(2017, 1, 1, 1, 14, 16, 202000), datetime.datetime(2017, 1, 1, 1, 14, 17, 374000)), 'overlap': datetime.timedelta(0, 1, 172000)}]
#
# {'caption': u'(GRUNTS)', 'ival': (datetime.datetime(2017, 1, 1, 1, 14, 16, 202000), datetime.datetime(2017, 1, 1, 1, 14, 17, 374000)), 'overlap': datetime.timedelta(0, 1, 172000)}
# {'caption': u'(GRUNTS)', 'ival': (datetime.datetime(2017, 1, 1, 1, 14, 16, 202000), datetime.datetime(2017, 1, 1, 1, 14, 17, 374000)), 'overlap': datetime.timedelta(0, 1, 172000)}
#
# [{'caption': u'Cheers.', 'ival': (datetime.datetime(2017, 1, 1, 0, 10, 41, 391000), datetime.datetime(2017, 1, 1, 0, 10, 42, 608000)), 'overlap': datetime.timedelta(0, 1, 217000)}]
# 乾杯
# {'caption': u'Cheers.', 'ival': (datetime.datetime(2017, 1, 1, 0, 10, 41, 391000), datetime.datetime(2017, 1, 1, 0, 10, 42, 608000)), 'overlap': datetime.timedelta(0, 1, 217000)}
# {'caption': u'Cheers.', 'ival': (datetime.datetime(2017, 1, 1, 0, 10, 41, 391000), datetime.datetime(2017, 1, 1, 0, 10, 42, 608000)), 'overlap': datetime.timedelta(0, 1, 217000)}
#
# [{'caption': u'How does such come to pass?', 'ival': (datetime.datetime(2017, 1, 1, 1, 29, 40, 83000), datetime.datetime(2017, 1, 1, 1, 29, 41, 835000)), 'overlap': datetime.timedelta(0, 1, 752000)}]
# よく耐えたもんだ
# {'caption': u'How does such come to pass?', 'ival': (datetime.datetime(2017, 1, 1, 1, 29, 40, 83000), datetime.datetime(2017, 1, 1, 1, 29, 41, 835000)), 'overlap': datetime.timedelta(0, 1, 752000)}
# {'caption': u'How does such come to pass?', 'ival': (datetime.datetime(2017, 1, 1, 1, 29, 40, 83000), datetime.datetime(2017, 1, 1, 1, 29, 41, 835000)), 'overlap': datetime.timedelta(0, 1, 752000)}
#
# [{'caption': u"She run off, ain't she?", 'ival': (datetime.datetime(2017, 1, 1, 1, 45, 55, 599000), datetime.datetime(2017, 1, 1, 1, 45, 56, 600000)), 'overlap': datetime.timedelta(0, 1, 1000)}]
# 逃げたのか？
# {'caption': u"She run off, ain't she?", 'ival': (datetime.datetime(2017, 1, 1, 1, 45, 55, 599000), datetime.datetime(2017, 1, 1, 1, 45, 56, 600000)), 'overlap': datetime.timedelta(0, 1, 1000)}
# {'caption': u"She run off, ain't she?", 'ival': (datetime.datetime(2017, 1, 1, 1, 45, 55, 599000), datetime.datetime(2017, 1, 1, 1, 45, 56, 600000)), 'overlap': datetime.timedelta(0, 1, 1000)}
#
# [{'caption': u'It is the custom.', 'ival': (datetime.datetime(2017, 1, 1, 0, 7, 52, 222000), datetime.datetime(2017, 1, 1, 0, 7, 54, 395000)), 'overlap': datetime.timedelta(0, 2, 173000)}]
# それが決まりよ
# {'caption': u'It is the custom.', 'ival': (datetime.datetime(2017, 1, 1, 0, 7, 52, 222000), datetime.datetime(2017, 1, 1, 0, 7, 54, 395000)), 'overlap': datetime.timedelta(0, 2, 173000)}
# {'caption': u'It is the custom.', 'ival': (datetime.datetime(2017, 1, 1, 0, 7, 52, 222000), datetime.datetime(2017, 1, 1, 0, 7, 54, 395000)), 'overlap': datetime.timedelta(0, 2, 173000)}
#
# [{'caption': u'Platt.', 'ival': (datetime.datetime(2017, 1, 1, 0, 28, 16, 28000), datetime.datetime(2017, 1, 1, 0, 28, 17, 120000)), 'overlap': datetime.timedelta(0, 1, 92000)}]
# プラット
# {'caption': u'Platt.', 'ival': (datetime.datetime(2017, 1, 1, 0, 28, 16, 28000), datetime.datetime(2017, 1, 1, 0, 28, 17, 120000)), 'overlap': datetime.timedelta(0, 1, 92000)}
# {'caption': u'Platt.', 'ival': (datetime.datetime(2017, 1, 1, 0, 28, 16, 28000), datetime.datetime(2017, 1, 1, 0, 28, 17, 120000)), 'overlap': datetime.timedelta(0, 1, 92000)}
#
# [{'caption': u'(PLAYING UPBEAT TUNE)', 'ival': (datetime.datetime(2017, 1, 1, 0, 6, 31, 641000), datetime.datetime(2017, 1, 1, 0, 6, 33, 188000)), 'overlap': datetime.timedelta(0, 1, 547000)}]
#
# {'caption': u'(PLAYING UPBEAT TUNE)', 'ival': (datetime.datetime(2017, 1, 1, 0, 6, 31, 641000), datetime.datetime(2017, 1, 1, 0, 6, 33, 188000)), 'overlap': datetime.timedelta(0, 1, 547000)}
# {'caption': u'(PLAYING UPBEAT TUNE)', 'ival': (datetime.datetime(2017, 1, 1, 0, 6, 31, 641000), datetime.datetime(2017, 1, 1, 0, 6, 33, 188000)), 'overlap': datetime.timedelta(0, 1, 547000)}
#
# [{'caption': u'Where am I going?\nWhere am I going, Sam?', 'ival': (datetime.datetime(2017, 1, 1, 0, 43, 41, 536000), datetime.datetime(2017, 1, 1, 0, 43, 43, 880000)), 'overlap': datetime.timedelta(0, 2, 344000)}]
# どこへ行くのです？
# {'caption': u'Where am I going?\nWhere am I going, Sam?', 'ival': (datetime.datetime(2017, 1, 1, 0, 43, 41, 536000), datetime.datetime(2017, 1, 1, 0, 43, 43, 880000)), 'overlap': datetime.timedelta(0, 2, 344000)}
# {'caption': u'Where am I going?\nWhere am I going, Sam?', 'ival': (datetime.datetime(2017, 1, 1, 0, 43, 41, 536000), datetime.datetime(2017, 1, 1, 0, 43, 43, 880000)), 'overlap': datetime.timedelta(0, 2, 344000)}
#
# [{'caption': u'And if it brings you your freedom,', 'ival': (datetime.datetime(2017, 1, 1, 1, 58, 9, 874000), datetime.datetime(2017, 1, 1, 1, 58, 11)), 'overlap': datetime.timedelta(0, 1, 126000)}]
# それで自由になるのなら
# {'caption': u'And if it brings you your freedom,', 'ival': (datetime.datetime(2017, 1, 1, 1, 58, 9, 874000), datetime.datetime(2017, 1, 1, 1, 58, 11)), 'overlap': datetime.timedelta(0, 1, 126000)}
# {'caption': u'And if it brings you your freedom,', 'ival': (datetime.datetime(2017, 1, 1, 1, 58, 9, 874000), datetime.datetime(2017, 1, 1, 1, 58, 11)), 'overlap': datetime.timedelta(0, 1, 126000)}
#
# [{'caption': u'by sorrow, you will drown in it.', 'ival': (datetime.datetime(2017, 1, 1, 0, 40, 5, 153000), datetime.datetime(2017, 1, 1, 0, 40, 6, 621000)), 'overlap': datetime.timedelta(0, 1, 468000)}]
# 自分が参ってしまうぞ
# {'caption': u'by sorrow, you will drown in it.', 'ival': (datetime.datetime(2017, 1, 1, 0, 40, 5, 153000), datetime.datetime(2017, 1, 1, 0, 40, 6, 621000)), 'overlap': datetime.timedelta(0, 1, 468000)}
# {'caption': u'by sorrow, you will drown in it.', 'ival': (datetime.datetime(2017, 1, 1, 0, 40, 5, 153000), datetime.datetime(2017, 1, 1, 0, 40, 6, 621000)), 'overlap': datetime.timedelta(0, 1, 468000)}
#
# [{'caption': u"Back to that hog's trough\nwhere I found you?", 'ival': (datetime.datetime(2017, 1, 1, 1, 0, 58, 363000), datetime.datetime(2017, 1, 1, 1, 1, 0, 661000)), 'overlap': datetime.timedelta(0, 2, 298000)}]
# あんな場所にに
# 戻りたくないだろう
# {'caption': u"Back to that hog's trough\nwhere I found you?", 'ival': (datetime.datetime(2017, 1, 1, 1, 0, 58, 363000), datetime.datetime(2017, 1, 1, 1, 1, 0, 661000)), 'overlap': datetime.timedelta(0, 2, 298000)}
# {'caption': u"Back to that hog's trough\nwhere I found you?", 'ival': (datetime.datetime(2017, 1, 1, 1, 0, 58, 363000), datetime.datetime(2017, 1, 1, 1, 1, 0, 661000)), 'overlap': datetime.timedelta(0, 2, 298000)}
#
# [{'caption': u'On my honor.', 'ival': (datetime.datetime(2017, 1, 1, 1, 32, 9, 149000), datetime.datetime(2017, 1, 1, 1, 32, 10, 150000)), 'overlap': datetime.timedelta(0, 1, 1000)}]
# 名誉の元に誓う
# {'caption': u'On my honor.', 'ival': (datetime.datetime(2017, 1, 1, 1, 32, 9, 149000), datetime.datetime(2017, 1, 1, 1, 32, 10, 150000)), 'overlap': datetime.timedelta(0, 1, 1000)}
# {'caption': u'On my honor.', 'ival': (datetime.datetime(2017, 1, 1, 1, 32, 9, 149000), datetime.datetime(2017, 1, 1, 1, 32, 10, 150000)), 'overlap': datetime.timedelta(0, 1, 1000)}
#
# [{'caption': u'a difficult time...', 'ival': (datetime.datetime(2017, 1, 1, 2, 5, 20, 722000), datetime.datetime(2017, 1, 1, 2, 5, 22, 690000)), 'overlap': datetime.timedelta(0, 1, 968000)}]
# 過酷な時を...
# {'caption': u'a difficult time...', 'ival': (datetime.datetime(2017, 1, 1, 2, 5, 20, 722000), datetime.datetime(2017, 1, 1, 2, 5, 22, 690000)), 'overlap': datetime.timedelta(0, 1, 968000)}
# {'caption': u'a difficult time...', 'ival': (datetime.datetime(2017, 1, 1, 2, 5, 20, 722000), datetime.datetime(2017, 1, 1, 2, 5, 22, 690000)), 'overlap': datetime.timedelta(0, 1, 968000)}
#
# [{'caption': u"I'll cut your black throat!", 'ival': (datetime.datetime(2017, 1, 1, 1, 10, 35, 815000), datetime.datetime(2017, 1, 1, 1, 10, 37, 567000)), 'overlap': datetime.timedelta(0, 1, 752000)}]
# 黒い喉を切ってやる
# {'caption': u"I'll cut your black throat!", 'ival': (datetime.datetime(2017, 1, 1, 1, 10, 35, 815000), datetime.datetime(2017, 1, 1, 1, 10, 37, 567000)), 'overlap': datetime.timedelta(0, 1, 752000)}
# {'caption': u"I'll cut your black throat!", 'ival': (datetime.datetime(2017, 1, 1, 1, 10, 35, 815000), datetime.datetime(2017, 1, 1, 1, 10, 37, 567000)), 'overlap': datetime.timedelta(0, 1, 752000)}
#
# [{'caption': u'I became a little too\ndependent on the whiskey...', 'ival': (datetime.datetime(2017, 1, 1, 1, 30, 9, 154000), datetime.datetime(2017, 1, 1, 1, 30, 12, 124000)), 'overlap': datetime.timedelta(0, 2, 970000)}]
# ウイスキー中毒
# になっていて
# {'caption': u'I became a little too\ndependent on the whiskey...', 'ival': (datetime.datetime(2017, 1, 1, 1, 30, 9, 154000), datetime.datetime(2017, 1, 1, 1, 30, 12, 124000)), 'overlap': datetime.timedelta(0, 2, 970000)}
# {'caption': u'I became a little too\ndependent on the whiskey...', 'ival': (datetime.datetime(2017, 1, 1, 1, 30, 9, 154000), datetime.datetime(2017, 1, 1, 1, 30, 12, 124000)), 'overlap': datetime.timedelta(0, 2, 970000)}
#
# [{'caption': u"It's all a lie.", 'ival': (datetime.datetime(2017, 1, 1, 1, 36, 30, 868000), datetime.datetime(2017, 1, 1, 1, 36, 32, 870000)), 'overlap': datetime.timedelta(0, 2, 2000)}]
# すべて嘘です
# {'caption': u"It's all a lie.", 'ival': (datetime.datetime(2017, 1, 1, 1, 36, 30, 868000), datetime.datetime(2017, 1, 1, 1, 36, 32, 870000)), 'overlap': datetime.timedelta(0, 2, 2000)}
# {'caption': u"It's all a lie.", 'ival': (datetime.datetime(2017, 1, 1, 1, 36, 30, 868000), datetime.datetime(2017, 1, 1, 1, 36, 32, 870000)), 'overlap': datetime.timedelta(0, 2, 2000)}
#
# [{'caption': u'(PATSEY SOBBING)', 'ival': (datetime.datetime(2017, 1, 1, 1, 50, 58, 986000), datetime.datetime(2017, 1, 1, 1, 51, 0, 659000)), 'overlap': datetime.timedelta(0, 1, 673000)}]
#
# {'caption': u'(PATSEY SOBBING)', 'ival': (datetime.datetime(2017, 1, 1, 1, 50, 58, 986000), datetime.datetime(2017, 1, 1, 1, 51, 0, 659000)), 'overlap': datetime.timedelta(0, 1, 673000)}
# {'caption': u'(PATSEY SOBBING)', 'ival': (datetime.datetime(2017, 1, 1, 1, 50, 58, 986000), datetime.datetime(2017, 1, 1, 1, 51, 0, 659000)), 'overlap': datetime.timedelta(0, 1, 673000)}
#
# [{'caption': u'God damn you! Get her out of here, Cape!\n(CHILDREN SCREAMING)', 'ival': (datetime.datetime(2017, 1, 1, 0, 31, 37, 312000), datetime.datetime(2017, 1, 1, 0, 31, 40, 31000)), 'overlap': datetime.timedelta(0, 2, 719000)}]
# なんてやつだ！ここから出せ！
# {'caption': u'God damn you! Get her out of here, Cape!\n(CHILDREN SCREAMING)', 'ival': (datetime.datetime(2017, 1, 1, 0, 31, 37, 312000), datetime.datetime(2017, 1, 1, 0, 31, 40, 31000)), 'overlap': datetime.timedelta(0, 2, 719000)}
# {'caption': u'God damn you! Get her out of here, Cape!\n(CHILDREN SCREAMING)', 'ival': (datetime.datetime(2017, 1, 1, 0, 31, 37, 312000), datetime.datetime(2017, 1, 1, 0, 31, 40, 31000)), 'overlap': datetime.timedelta(0, 2, 719000)}
#
# [{'caption': u'And you know what of\ntransport and terraforming?', 'ival': (datetime.datetime(2017, 1, 1, 0, 37, 1, 10000), datetime.datetime(2017, 1, 1, 0, 37, 3, 763000)), 'overlap': datetime.timedelta(0, 2, 753000)}]
# 水路の搬送について
# 知ってんのか？
# {'caption': u'And you know what of\ntransport and terraforming?', 'ival': (datetime.datetime(2017, 1, 1, 0, 37, 1, 10000), datetime.datetime(2017, 1, 1, 0, 37, 3, 763000)), 'overlap': datetime.timedelta(0, 2, 753000)}
# {'caption': u'And you know what of\ntransport and terraforming?', 'ival': (datetime.datetime(2017, 1, 1, 0, 37, 1, 10000), datetime.datetime(2017, 1, 1, 0, 37, 3, 763000)), 'overlap': datetime.timedelta(0, 2, 753000)}
#
# [{'caption': u"Don't want to\nfrighten the children", 'ival': (datetime.datetime(2017, 1, 1, 0, 19, 31, 754000), datetime.datetime(2017, 1, 1, 0, 19, 33, 347000)), 'overlap': datetime.timedelta(0, 1, 593000)}]
# 子供らを怖がらせたいのか？
# {'caption': u"Don't want to\nfrighten the children", 'ival': (datetime.datetime(2017, 1, 1, 0, 19, 31, 754000), datetime.datetime(2017, 1, 1, 0, 19, 33, 347000)), 'overlap': datetime.timedelta(0, 1, 593000)}
# {'caption': u"Don't want to\nfrighten the children", 'ival': (datetime.datetime(2017, 1, 1, 0, 19, 31, 754000), datetime.datetime(2017, 1, 1, 0, 19, 33, 347000)), 'overlap': datetime.timedelta(0, 1, 593000)}
#
# [{'caption': u'(MUSIC FADES)', 'ival': (datetime.datetime(2017, 1, 1, 1, 26, 2, 449000), datetime.datetime(2017, 1, 1, 1, 26, 4, 76000)), 'overlap': datetime.timedelta(0, 1, 627000)}]
#
# {'caption': u'(MUSIC FADES)', 'ival': (datetime.datetime(2017, 1, 1, 1, 26, 2, 449000), datetime.datetime(2017, 1, 1, 1, 26, 4, 76000)), 'overlap': datetime.timedelta(0, 1, 627000)}
# {'caption': u'(MUSIC FADES)', 'ival': (datetime.datetime(2017, 1, 1, 1, 26, 2, 449000), datetime.datetime(2017, 1, 1, 1, 26, 4, 76000)), 'overlap': datetime.timedelta(0, 1, 627000)}
#
# [{'caption': u'Mmm.', 'ival': (datetime.datetime(2017, 1, 1, 0, 28, 50, 145000), datetime.datetime(2017, 1, 1, 0, 28, 51, 317000)), 'overlap': datetime.timedelta(0, 1, 172000)}]
#
# {'caption': u'Mmm.', 'ival': (datetime.datetime(2017, 1, 1, 0, 28, 50, 145000), datetime.datetime(2017, 1, 1, 0, 28, 51, 317000)), 'overlap': datetime.timedelta(0, 1, 172000)}
# {'caption': u'Mmm.', 'ival': (datetime.datetime(2017, 1, 1, 0, 28, 50, 145000), datetime.datetime(2017, 1, 1, 0, 28, 51, 317000)), 'overlap': datetime.timedelta(0, 1, 172000)}
#
# [{'caption': u'she gained power\nof the household...', 'ival': (datetime.datetime(2017, 1, 1, 0, 44, 44, 974000), datetime.datetime(2017, 1, 1, 0, 44, 46, 601000)), 'overlap': datetime.timedelta(0, 1, 627000)}]
# 彼女が主権を握り
# {'caption': u'she gained power\nof the household...', 'ival': (datetime.datetime(2017, 1, 1, 0, 44, 44, 974000), datetime.datetime(2017, 1, 1, 0, 44, 46, 601000)), 'overlap': datetime.timedelta(0, 1, 627000)}
# {'caption': u'she gained power\nof the household...', 'ival': (datetime.datetime(2017, 1, 1, 0, 44, 44, 974000), datetime.datetime(2017, 1, 1, 0, 44, 46, 601000)), 'overlap': datetime.timedelta(0, 1, 627000)}
#
# [{'caption': u'or he finds some way to trample\nhis guilty sensations.', 'ival': (datetime.datetime(2017, 1, 1, 1, 30, 43, 521000), datetime.datetime(2017, 1, 1, 1, 30, 46, 866000)), 'overlap': datetime.timedelta(0, 3, 345000)}]
# 罪を忘れるために飲む
# {'caption': u'or he finds some way to trample\nhis guilty sensations.', 'ival': (datetime.datetime(2017, 1, 1, 1, 30, 43, 521000), datetime.datetime(2017, 1, 1, 1, 30, 46, 866000)), 'overlap': datetime.timedelta(0, 3, 345000)}
# {'caption': u'or he finds some way to trample\nhis guilty sensations.', 'ival': (datetime.datetime(2017, 1, 1, 1, 30, 43, 521000), datetime.datetime(2017, 1, 1, 1, 30, 46, 866000)), 'overlap': datetime.timedelta(0, 3, 345000)}
#
# [{'caption': u'Get away from him, Pats.', 'ival': (datetime.datetime(2017, 1, 1, 2, 3, 20, 935000), datetime.datetime(2017, 1, 1, 2, 3, 22, 152000)), 'overlap': datetime.timedelta(0, 1, 217000)}]
# 離れろパッツ！
# {'caption': u'Get away from him, Pats.', 'ival': (datetime.datetime(2017, 1, 1, 2, 3, 20, 935000), datetime.datetime(2017, 1, 1, 2, 3, 22, 152000)), 'overlap': datetime.timedelta(0, 1, 217000)}
# {'caption': u'Get away from him, Pats.', 'ival': (datetime.datetime(2017, 1, 1, 2, 3, 20, 935000), datetime.datetime(2017, 1, 1, 2, 3, 22, 152000)), 'overlap': datetime.timedelta(0, 1, 217000)}
#
# [{'caption': u'Man does how he pleases\nwith his property.', 'ival': (datetime.datetime(2017, 1, 1, 1, 52, 24, 488000), datetime.datetime(2017, 1, 1, 1, 52, 27, 412000)), 'overlap': datetime.timedelta(0, 2, 924000)}]
# 自分の所有物を
# どうしようと俺の勝手だ
# {'caption': u'Man does how he pleases\nwith his property.', 'ival': (datetime.datetime(2017, 1, 1, 1, 52, 24, 488000), datetime.datetime(2017, 1, 1, 1, 52, 27, 412000)), 'overlap': datetime.timedelta(0, 2, 924000)}
# {'caption': u'Man does how he pleases\nwith his property.', 'ival': (datetime.datetime(2017, 1, 1, 1, 52, 24, 488000), datetime.datetime(2017, 1, 1, 1, 52, 27, 412000)), 'overlap': datetime.timedelta(0, 2, 924000)}
#
# [{'caption': u'FORD: Platt.', 'ival': (datetime.datetime(2017, 1, 1, 0, 38, 41, 861000), datetime.datetime(2017, 1, 1, 0, 38, 43, 204000)), 'overlap': datetime.timedelta(0, 1, 343000)}]
# プラット
# {'caption': u'FORD: Platt.', 'ival': (datetime.datetime(2017, 1, 1, 0, 38, 41, 861000), datetime.datetime(2017, 1, 1, 0, 38, 43, 204000)), 'overlap': datetime.timedelta(0, 1, 343000)}
# {'caption': u'FORD: Platt.', 'ival': (datetime.datetime(2017, 1, 1, 0, 38, 41, 861000), datetime.datetime(2017, 1, 1, 0, 38, 43, 204000)), 'overlap': datetime.timedelta(0, 1, 343000)}
#
# [{'caption': u'Jasper!', 'ival': (datetime.datetime(2017, 1, 1, 0, 27, 29, 648000), datetime.datetime(2017, 1, 1, 0, 27, 30, 740000)), 'overlap': datetime.timedelta(0, 1, 92000)}]
# ジャスパー！
# {'caption': u'Jasper!', 'ival': (datetime.datetime(2017, 1, 1, 0, 27, 29, 648000), datetime.datetime(2017, 1, 1, 0, 27, 30, 740000)), 'overlap': datetime.timedelta(0, 1, 92000)}
# {'caption': u'Jasper!', 'ival': (datetime.datetime(2017, 1, 1, 0, 27, 29, 648000), datetime.datetime(2017, 1, 1, 0, 27, 30, 740000)), 'overlap': datetime.timedelta(0, 1, 92000)}
#
# [{'caption': u'Come here, boy.', 'ival': (datetime.datetime(2017, 1, 1, 1, 4, 26, 112000), datetime.datetime(2017, 1, 1, 1, 4, 27, 113000)), 'overlap': datetime.timedelta(0, 1, 1000)}]
# こっちへ来い
# {'caption': u'Come here, boy.', 'ival': (datetime.datetime(2017, 1, 1, 1, 4, 26, 112000), datetime.datetime(2017, 1, 1, 1, 4, 27, 113000)), 'overlap': datetime.timedelta(0, 1, 1000)}
# {'caption': u'Come here, boy.', 'ival': (datetime.datetime(2017, 1, 1, 1, 4, 26, 112000), datetime.datetime(2017, 1, 1, 1, 4, 27, 113000)), 'overlap': datetime.timedelta(0, 1, 1000)}
#
# [{'caption': u'(WHIMPERING)', 'ival': (datetime.datetime(2017, 1, 1, 1, 53, 13, 870000), datetime.datetime(2017, 1, 1, 1, 53, 15, 292000)), 'overlap': datetime.timedelta(0, 1, 422000)}]
#
# {'caption': u'(WHIMPERING)', 'ival': (datetime.datetime(2017, 1, 1, 1, 53, 13, 870000), datetime.datetime(2017, 1, 1, 1, 53, 15, 292000)), 'overlap': datetime.timedelta(0, 1, 422000)}
# {'caption': u'(WHIMPERING)', 'ival': (datetime.datetime(2017, 1, 1, 1, 53, 13, 870000), datetime.datetime(2017, 1, 1, 1, 53, 15, 292000)), 'overlap': datetime.timedelta(0, 1, 422000)}
#
# [{'caption': u'(SHOUTS)', 'ival': (datetime.datetime(2017, 1, 1, 1, 53, 20, 85000), datetime.datetime(2017, 1, 1, 1, 53, 21, 257000)), 'overlap': datetime.timedelta(0, 1, 172000)}]
#
# {'caption': u'(SHOUTS)', 'ival': (datetime.datetime(2017, 1, 1, 1, 53, 20, 85000), datetime.datetime(2017, 1, 1, 1, 53, 21, 257000)), 'overlap': datetime.timedelta(0, 1, 172000)}
# {'caption': u'(SHOUTS)', 'ival': (datetime.datetime(2017, 1, 1, 1, 53, 20, 85000), datetime.datetime(2017, 1, 1, 1, 53, 21, 257000)), 'overlap': datetime.timedelta(0, 1, 172000)}
#
# [{'caption': u"You're Judge Turner's\nfor the season.", 'ival': (datetime.datetime(2017, 1, 1, 1, 22, 45, 836000), datetime.datetime(2017, 1, 1, 1, 22, 47, 713000)), 'overlap': datetime.timedelta(0, 1, 877000)}]
# 私が収穫できるようになるまで
# 人手を必要としている
# {'caption': u"You're Judge Turner's\nfor the season.", 'ival': (datetime.datetime(2017, 1, 1, 1, 22, 45, 836000), datetime.datetime(2017, 1, 1, 1, 22, 47, 713000)), 'overlap': datetime.timedelta(0, 1, 877000)}
# {'caption': u"You're Judge Turner's\nfor the season.", 'ival': (datetime.datetime(2017, 1, 1, 1, 22, 45, 836000), datetime.datetime(2017, 1, 1, 1, 22, 47, 713000)), 'overlap': datetime.timedelta(0, 1, 877000)}
#
# [{'caption': u"Won't be no hell for you.", 'ival': (datetime.datetime(2017, 1, 1, 1, 20, 26, 822000), datetime.datetime(2017, 1, 1, 1, 20, 29, 325000)), 'overlap': datetime.timedelta(0, 2, 503000)}]
# あなたならできるわ
# {'caption': u"Won't be no hell for you.", 'ival': (datetime.datetime(2017, 1, 1, 1, 20, 26, 822000), datetime.datetime(2017, 1, 1, 1, 20, 29, 325000)), 'overlap': datetime.timedelta(0, 2, 503000)}
# {'caption': u"Won't be no hell for you.", 'ival': (datetime.datetime(2017, 1, 1, 1, 20, 26, 822000), datetime.datetime(2017, 1, 1, 1, 20, 29, 325000)), 'overlap': datetime.timedelta(0, 2, 503000)}
#
# [{'caption': u'Superb. A moment, please.', 'ival': (datetime.datetime(2017, 1, 1, 0, 30, 49, 264000), datetime.datetime(2017, 1, 1, 0, 30, 51, 608000)), 'overlap': datetime.timedelta(0, 2, 344000)}]
# 少々お待ちを
# {'caption': u'Superb. A moment, please.', 'ival': (datetime.datetime(2017, 1, 1, 0, 30, 49, 264000), datetime.datetime(2017, 1, 1, 0, 30, 51, 608000)), 'overlap': datetime.timedelta(0, 2, 344000)}
# {'caption': u'Superb. A moment, please.', 'ival': (datetime.datetime(2017, 1, 1, 0, 30, 49, 264000), datetime.datetime(2017, 1, 1, 0, 30, 51, 608000)), 'overlap': datetime.timedelta(0, 2, 344000)}
#
# [{'caption': u'And so, I did.', 'ival': (datetime.datetime(2017, 1, 1, 0, 45, 48, 79000), datetime.datetime(2017, 1, 1, 0, 45, 49, 752000)), 'overlap': datetime.timedelta(0, 1, 673000)}]
# 使いました
# {'caption': u'And so, I did.', 'ival': (datetime.datetime(2017, 1, 1, 0, 45, 48, 79000), datetime.datetime(2017, 1, 1, 0, 45, 49, 752000)), 'overlap': datetime.timedelta(0, 1, 673000)}
# {'caption': u'And so, I did.', 'ival': (datetime.datetime(2017, 1, 1, 0, 45, 48, 79000), datetime.datetime(2017, 1, 1, 0, 45, 49, 752000)), 'overlap': datetime.timedelta(0, 1, 673000)}
#
# [{'caption': u"It's the Lord's day.", 'ival': (datetime.datetime(2017, 1, 1, 1, 11, 33, 372000), datetime.datetime(2017, 1, 1, 1, 11, 35, 249000)), 'overlap': datetime.timedelta(0, 1, 877000)}]
# 今日は日曜だ
# {'caption': u"It's the Lord's day.", 'ival': (datetime.datetime(2017, 1, 1, 1, 11, 33, 372000), datetime.datetime(2017, 1, 1, 1, 11, 35, 249000)), 'overlap': datetime.timedelta(0, 1, 877000)}
# {'caption': u"It's the Lord's day.", 'ival': (datetime.datetime(2017, 1, 1, 1, 11, 33, 372000), datetime.datetime(2017, 1, 1, 1, 11, 35, 249000)), 'overlap': datetime.timedelta(0, 1, 877000)}
#
# ...
# {'caption': u"I ain't even spoken with him today.", 'ival': (datetime.datetime(2017, 1, 1, 1, 12, 24, 882000), datetime.datetime(2017, 1, 1, 1, 12, 26, 759000)), 'overlap': datetime.timedelta(0, 1, 877000)}
#
# [{'caption': u'As you are aware...', 'ival': (datetime.datetime(2017, 1, 1, 1, 7, 56, 72000), datetime.datetime(2017, 1, 1, 1, 7, 58, 120000)), 'overlap': datetime.timedelta(0, 2, 48000)}]
# 何事も程ほどに
# {'caption': u'As you are aware...', 'ival': (datetime.datetime(2017, 1, 1, 1, 7, 56, 72000), datetime.datetime(2017, 1, 1, 1, 7, 58, 120000)), 'overlap': datetime.timedelta(0, 2, 48000)}
# {'caption': u'As you are aware...', 'ival': (datetime.datetime(2017, 1, 1, 1, 7, 56, 72000), datetime.datetime(2017, 1, 1, 1, 7, 58, 120000)), 'overlap': datetime.timedelta(0, 2, 48000)}
#
# [{'caption': u'Husband.', 'ival': (datetime.datetime(2017, 1, 1, 2, 6, 17, 320000), datetime.datetime(2017, 1, 1, 2, 6, 18, 492000)), 'overlap': datetime.timedelta(0, 1, 172000)}]
# 主人
# {'caption': u'Husband.', 'ival': (datetime.datetime(2017, 1, 1, 2, 6, 17, 320000), datetime.datetime(2017, 1, 1, 2, 6, 18, 492000)), 'overlap': datetime.timedelta(0, 1, 172000)}
# {'caption': u'Husband.', 'ival': (datetime.datetime(2017, 1, 1, 2, 6, 17, 320000), datetime.datetime(2017, 1, 1, 2, 6, 18, 492000)), 'overlap': datetime.timedelta(0, 1, 172000)}
#
# [{'caption': u'Into bed.\nThank you for the music.', 'ival': (datetime.datetime(2017, 1, 1, 0, 7, 13, 433000), datetime.datetime(2017, 1, 1, 0, 7, 15, 26000)), 'overlap': datetime.timedelta(0, 1, 593000)}]
# 演奏ありがとな
# {'caption': u'Into bed.\nThank you for the music.', 'ival': (datetime.datetime(2017, 1, 1, 0, 7, 13, 433000), datetime.datetime(2017, 1, 1, 0, 7, 15, 26000)), 'overlap': datetime.timedelta(0, 1, 593000)}
# {'caption': u'Into bed.\nThank you for the music.', 'ival': (datetime.datetime(2017, 1, 1, 0, 7, 13, 433000), datetime.datetime(2017, 1, 1, 0, 7, 15, 26000)), 'overlap': datetime.timedelta(0, 1, 593000)}
#
# [{'caption': u'And you have no right\nwhatsoever to detain me.', 'ival': (datetime.datetime(2017, 1, 1, 0, 13, 21, 968000), datetime.datetime(2017, 1, 1, 0, 13, 23, 845000)), 'overlap': datetime.timedelta(0, 1, 877000)}]
# 私を拘留する権利はない
# {'caption': u'And you have no right\nwhatsoever to detain me.', 'ival': (datetime.datetime(2017, 1, 1, 0, 13, 21, 968000), datetime.datetime(2017, 1, 1, 0, 13, 23, 845000)), 'overlap': datetime.timedelta(0, 1, 877000)}
# {'caption': u'And you have no right\nwhatsoever to detain me.', 'ival': (datetime.datetime(2017, 1, 1, 0, 13, 21, 968000), datetime.datetime(2017, 1, 1, 0, 13, 23, 845000)), 'overlap': datetime.timedelta(0, 1, 877000)}
#
# [{'caption': u'Platt?', 'ival': (datetime.datetime(2017, 1, 1, 1, 28, 56, 81000), datetime.datetime(2017, 1, 1, 1, 28, 57, 298000)), 'overlap': datetime.timedelta(0, 1, 217000)}]
# プラット
# {'caption': u'Platt?', 'ival': (datetime.datetime(2017, 1, 1, 1, 28, 56, 81000), datetime.datetime(2017, 1, 1, 1, 28, 57, 298000)), 'overlap': datetime.timedelta(0, 1, 217000)}
# {'caption': u'Platt?', 'ival': (datetime.datetime(2017, 1, 1, 1, 28, 56, 81000), datetime.datetime(2017, 1, 1, 1, 28, 57, 298000)), 'overlap': datetime.timedelta(0, 1, 217000)}
#
# [{'caption': u'Two of them?\nYou got two?', 'ival': (datetime.datetime(2017, 1, 1, 0, 32, 20, 856000), datetime.datetime(2017, 1, 1, 0, 32, 23, 109000)), 'overlap': datetime.timedelta(0, 2, 253000)}]
# 二人？
# 二人ね？
# {'caption': u'Two of them?\nYou got two?', 'ival': (datetime.datetime(2017, 1, 1, 0, 32, 20, 856000), datetime.datetime(2017, 1, 1, 0, 32, 23, 109000)), 'overlap': datetime.timedelta(0, 2, 253000)}
# {'caption': u'Two of them?\nYou got two?', 'ival': (datetime.datetime(2017, 1, 1, 0, 32, 20, 856000), datetime.datetime(2017, 1, 1, 0, 32, 23, 109000)), 'overlap': datetime.timedelta(0, 2, 253000)}
#
# [{'caption': u'Go on, wash up.', 'ival': (datetime.datetime(2017, 1, 1, 0, 17, 37, 890000), datetime.datetime(2017, 1, 1, 0, 17, 39, 642000)), 'overlap': datetime.timedelta(0, 1, 752000)}]
# 洗ってるか
# {'caption': u'Go on, wash up.', 'ival': (datetime.datetime(2017, 1, 1, 0, 17, 37, 890000), datetime.datetime(2017, 1, 1, 0, 17, 39, 642000)), 'overlap': datetime.timedelta(0, 1, 752000)}
# {'caption': u'Go on, wash up.', 'ival': (datetime.datetime(2017, 1, 1, 0, 17, 37, 890000), datetime.datetime(2017, 1, 1, 0, 17, 39, 642000)), 'overlap': datetime.timedelta(0, 1, 752000)}
#
# [{'caption': u'let me state my case.', 'ival': (datetime.datetime(2017, 1, 1, 1, 30, 18, 955000), datetime.datetime(2017, 1, 1, 1, 30, 21, 83000)), 'overlap': datetime.timedelta(0, 2, 128000)}]
# ...説明させてくれ
# {'caption': u'let me state my case.', 'ival': (datetime.datetime(2017, 1, 1, 1, 30, 18, 955000), datetime.datetime(2017, 1, 1, 1, 30, 21, 83000)), 'overlap': datetime.timedelta(0, 2, 128000)}
# {'caption': u'let me state my case.', 'ival': (datetime.datetime(2017, 1, 1, 1, 30, 18, 955000), datetime.datetime(2017, 1, 1, 1, 30, 21, 83000)), 'overlap': datetime.timedelta(0, 2, 128000)}
#
# [{'caption': u'Strike the life from her.', 'ival': (datetime.datetime(2017, 1, 1, 1, 49, 0, 868000), datetime.datetime(2017, 1, 1, 1, 49, 3, 87000)), 'overlap': datetime.timedelta(0, 2, 219000)}]
# 死ぬまで叩き続けて
# {'caption': u'Strike the life from her.', 'ival': (datetime.datetime(2017, 1, 1, 1, 49, 0, 868000), datetime.datetime(2017, 1, 1, 1, 49, 3, 87000)), 'overlap': datetime.timedelta(0, 2, 219000)}
# {'caption': u'Strike the life from her.', 'ival': (datetime.datetime(2017, 1, 1, 1, 49, 0, 868000), datetime.datetime(2017, 1, 1, 1, 49, 3, 87000)), 'overlap': datetime.timedelta(0, 2, 219000)}
#
# [{'caption': u'You will not take them from me!', 'ival': (datetime.datetime(2017, 1, 1, 0, 31, 36, 19000), datetime.datetime(2017, 1, 1, 0, 31, 37, 259000)), 'overlap': datetime.timedelta(0, 1, 240000)}]
# 私から奪わないで！
# {'caption': u'You will not take them from me!', 'ival': (datetime.datetime(2017, 1, 1, 0, 31, 36, 19000), datetime.datetime(2017, 1, 1, 0, 31, 37, 259000)), 'overlap': datetime.timedelta(0, 1, 240000)}
# {'caption': u'You will not take them from me!', 'ival': (datetime.datetime(2017, 1, 1, 0, 31, 36, 19000), datetime.datetime(2017, 1, 1, 0, 31, 37, 259000)), 'overlap': datetime.timedelta(0, 1, 240000)}
#
# [{'caption': u"Now, them cane ain't gonna\njump up and bite you.", 'ival': (datetime.datetime(2017, 1, 1, 0, 1, 31, 300000), datetime.datetime(2017, 1, 1, 0, 1, 33, 769000)), 'overlap': datetime.timedelta(0, 2, 469000)}]
# 飛びついて噛んだりしないから
# {'caption': u"Now, them cane ain't gonna\njump up and bite you.", 'ival': (datetime.datetime(2017, 1, 1, 0, 1, 31, 300000), datetime.datetime(2017, 1, 1, 0, 1, 33, 769000)), 'overlap': datetime.timedelta(0, 2, 469000)}
# {'caption': u"Now, them cane ain't gonna\njump up and bite you.", 'ival': (datetime.datetime(2017, 1, 1, 0, 1, 31, 300000), datetime.datetime(2017, 1, 1, 0, 1, 33, 769000)), 'overlap': datetime.timedelta(0, 2, 469000)}
#
# [{'caption': u'He learn you to read?', 'ival': (datetime.datetime(2017, 1, 1, 1, 3, 2, 487000), datetime.datetime(2017, 1, 1, 1, 3, 3, 909000)), 'overlap': datetime.timedelta(0, 1, 422000)}]
# 読み方を教えてくれた？
# {'caption': u'He learn you to read?', 'ival': (datetime.datetime(2017, 1, 1, 1, 3, 2, 487000), datetime.datetime(2017, 1, 1, 1, 3, 3, 909000)), 'overlap': datetime.timedelta(0, 1, 422000)}
# {'caption': u'He learn you to read?', 'ival': (datetime.datetime(2017, 1, 1, 1, 3, 2, 487000), datetime.datetime(2017, 1, 1, 1, 3, 3, 909000)), 'overlap': datetime.timedelta(0, 1, 422000)}
#
# [{'caption': u'The fact that I can walk out of here\ntomorrow brings me great pleasure.', 'ival': (datetime.datetime(2017, 1, 1, 1, 57, 29, 84000), datetime.datetime(2017, 1, 1, 1, 57, 33, 430000)), 'overlap': datetime.timedelta(0, 4, 346000)}]
# 明日にでもここを出て行く
# 喜びがある
# {'caption': u'The fact that I can walk out of here\ntomorrow brings me great pleasure.', 'ival': (datetime.datetime(2017, 1, 1, 1, 57, 29, 84000), datetime.datetime(2017, 1, 1, 1, 57, 33, 430000)), 'overlap': datetime.timedelta(0, 4, 346000)}
# {'caption': u'The fact that I can walk out of here\ntomorrow brings me great pleasure.', 'ival': (datetime.datetime(2017, 1, 1, 1, 57, 29, 84000), datetime.datetime(2017, 1, 1, 1, 57, 33, 430000)), 'overlap': datetime.timedelta(0, 4, 346000)}
#
# [{'caption': u'One so young will\nbring you no profit.', 'ival': (datetime.datetime(2017, 1, 1, 0, 30, 59, 274000), datetime.datetime(2017, 1, 1, 0, 31, 0, 947000)), 'overlap': datetime.timedelta(0, 1, 673000)}]
# 若くて価値もないはずだ
# {'caption': u'One so young will\nbring you no profit.', 'ival': (datetime.datetime(2017, 1, 1, 0, 30, 59, 274000), datetime.datetime(2017, 1, 1, 0, 31, 0, 947000)), 'overlap': datetime.timedelta(0, 1, 673000)}
# {'caption': u'One so young will\nbring you no profit.', 'ival': (datetime.datetime(2017, 1, 1, 0, 30, 59, 274000), datetime.datetime(2017, 1, 1, 0, 31, 0, 947000)), 'overlap': datetime.timedelta(0, 1, 673000)}
#
# [{'caption': u'Sun gonna set here', 'ival': (datetime.datetime(2017, 1, 1, 1, 38, 22, 438000), datetime.datetime(2017, 1, 1, 1, 38, 24, 315000)), 'overlap': datetime.timedelta(0, 1, 877000)}]
# Sun gonna set here
# {'caption': u'Sun gonna set here', 'ival': (datetime.datetime(2017, 1, 1, 1, 38, 22, 438000), datetime.datetime(2017, 1, 1, 1, 38, 24, 315000)), 'overlap': datetime.timedelta(0, 1, 877000)}
# {'caption': u'Sun gonna set here', 'ival': (datetime.datetime(2017, 1, 1, 1, 38, 22, 438000), datetime.datetime(2017, 1, 1, 1, 38, 24, 315000)), 'overlap': datetime.timedelta(0, 1, 877000)}
#
# [{'caption': u'No.', 'ival': (datetime.datetime(2017, 1, 1, 2, 3, 29, 152000), datetime.datetime(2017, 1, 1, 2, 3, 30, 153000)), 'overlap': datetime.timedelta(0, 1, 1000)}]
# いや
# {'caption': u'No.', 'ival': (datetime.datetime(2017, 1, 1, 2, 3, 29, 152000), datetime.datetime(2017, 1, 1, 2, 3, 30, 153000)), 'overlap': datetime.timedelta(0, 1, 1000)}
# {'caption': u'No.', 'ival': (datetime.datetime(2017, 1, 1, 2, 3, 29, 152000), datetime.datetime(2017, 1, 1, 2, 3, 30, 153000)), 'overlap': datetime.timedelta(0, 1, 1000)}
#
# [{'caption': u'between a white man and a baboon.', 'ival': (datetime.datetime(2017, 1, 1, 1, 44, 6, 949000), datetime.datetime(2017, 1, 1, 1, 44, 9, 327000)), 'overlap': datetime.timedelta(0, 2, 378000)}]
# 白人とヒヒみたいな違いだろ
# {'caption': u'between a white man and a baboon.', 'ival': (datetime.datetime(2017, 1, 1, 1, 44, 6, 949000), datetime.datetime(2017, 1, 1, 1, 44, 9, 327000)), 'overlap': datetime.timedelta(0, 2, 378000)}
# {'caption': u'between a white man and a baboon.', 'ival': (datetime.datetime(2017, 1, 1, 1, 44, 6, 949000), datetime.datetime(2017, 1, 1, 1, 44, 9, 327000)), 'overlap': datetime.timedelta(0, 2, 378000)}
#
# [{'caption': u'This is a list of\ngoods and sundries.', 'ival': (datetime.datetime(2017, 1, 1, 1, 2, 34, 334000), datetime.datetime(2017, 1, 1, 1, 2, 36, 86000)), 'overlap': datetime.timedelta(0, 1, 752000)}]
# 商品と小間物のリストよ
# {'caption': u'This is a list of\ngoods and sundries.', 'ival': (datetime.datetime(2017, 1, 1, 1, 2, 34, 334000), datetime.datetime(2017, 1, 1, 1, 2, 36, 86000)), 'overlap': datetime.timedelta(0, 1, 752000)}
# {'caption': u'This is a list of\ngoods and sundries.', 'ival': (datetime.datetime(2017, 1, 1, 1, 2, 34, 334000), datetime.datetime(2017, 1, 1, 1, 2, 36, 86000)), 'overlap': datetime.timedelta(0, 1, 752000)}
#
# [{'caption': u'Master Epps... You miserable wench.\nWhere you been?', 'ival': (datetime.datetime(2017, 1, 1, 1, 46, 55, 659000), datetime.datetime(2017, 1, 1, 1, 46, 57, 659000)), 'overlap': datetime.timedelta(0, 2)}]
# エップス様
# -哀れな女がどこに行ってた
# {'caption': u'Master Epps... You miserable wench.\nWhere you been?', 'ival': (datetime.datetime(2017, 1, 1, 1, 46, 55, 659000), datetime.datetime(2017, 1, 1, 1, 46, 57, 659000)), 'overlap': datetime.timedelta(0, 2)}
# {'caption': u'Master Epps... You miserable wench.\nWhere you been?', 'ival': (datetime.datetime(2017, 1, 1, 1, 46, 55, 659000), datetime.datetime(2017, 1, 1, 1, 46, 57, 659000)), 'overlap': datetime.timedelta(0, 2)}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-9baf48700940> in <module>()
#       8
#       9 for title in os.listdir(root):
# ---> 10     SUBS[title] = extract_subs_for_title(os.path.join(root, title), coverage_threshold)
#
# <ipython-input-31-440591b63842> in extract_subs_for_title(title_dir, coverage_threshold)
#      77 def extract_subs_for_title(title_dir, coverage_threshold):
#      78     ja_sub_mappings = gather_mappings(os.path.join(title_dir, 'ja'))
# ---> 79     en_sub_mappings = gather_mappings(os.path.join(title_dir, 'en'))
#      80
#      81     match_candidates = []
#
# <ipython-input-31-440591b63842> in gather_mappings(lang_dir)
#      71     out = {}
#      72     for subfile in os.listdir(lang_dir):
# ---> 73         out[subfile] = ts_caption_mapping(os.path.join(lang_dir, subfile))
#      74     return out
#      75
#
# <ipython-input-31-440591b63842> in ts_caption_mapping(f)
#      59         return datetime.datetime.combine(pivot, sub.start.to_time()),                datetime.datetime.combine(pivot, sub.end.to_time())
#      60
# ---> 61     subs = pysrt.open(f)
#      62     out = {}
#      63     for sub in subs:
#
# /usr/local/lib/python2.7/site-packages/pysrt/srtfile.pyc in open(cls, path, encoding, error_handling)
#     151         source_file, encoding = cls._open_unicode_file(path, claimed_encoding=encoding)
#     152         new_file = cls(path=path, encoding=encoding)
# --> 153         new_file.read(source_file, error_handling=error_handling)
#     154         source_file.close()
#     155         return new_file
#
# /usr/local/lib/python2.7/site-packages/pysrt/srtfile.pyc in read(self, source_file, error_handling)
#     179         """
#     180         self.eol = self._guess_eol(source_file)
# --> 181         self.extend(self.stream(source_file, error_handling=error_handling))
#     182         return self
#     183
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/UserList.pyc in extend(self, other)
#      86             self.data.extend(other.data)
#      87         else:
# ---> 88             self.data.extend(other)
#
# /usr/local/lib/python2.7/site-packages/pysrt/srtfile.pyc in stream(cls, source_file, error_handling)
#     210                 if source and all(source):
#     211                     try:
# --> 212                         yield SubRipItem.from_lines(source)
#     213                     except Error as error:
#     214                         error.args += (''.join(source), )
#
# /usr/local/lib/python2.7/site-packages/pysrt/srtitem.pyc in from_lines(cls, lines)
#      88         start, end, position = cls.split_timestamps(lines[0])
#      89         body = '\n'.join(lines[1:])
# ---> 90         return cls(index, start, end, body, position)
#      91
#      92     @classmethod
#
# /usr/local/lib/python2.7/site-packages/pysrt/srtitem.pyc in __init__(self, index, start, end, text, position)
#      30
#      31         self.start = SubRipTime.coerce(start or 0)
# ---> 32         self.end = SubRipTime.coerce(end or 0)
#      33         self.position = str(position)
#      34         self.text = str(text)
#
# /usr/local/lib/python2.7/site-packages/pysrt/srttime.pyc in coerce(cls, other)
#     108             return other
#     109         if isinstance(other, basestring):
# --> 110             return cls.from_string(other)
#     111         if isinstance(other, int):
#     112             return cls.from_ordinal(other)
#
# /usr/local/lib/python2.7/site-packages/pysrt/srttime.pyc in from_string(cls, source)
#     150         if len(items) != 4:
#     151             raise InvalidTimeString
# --> 152         return cls(*(cls.parse_int(i) for i in items))
#     153
#     154     @classmethod
#
# /usr/local/lib/python2.7/site-packages/pysrt/srttime.pyc in <genexpr>((i,))
#     150         if len(items) != 4:
#     151             raise InvalidTimeString
# --> 152         return cls(*(cls.parse_int(i) for i in items))
#     153
#     154     @classmethod
#
# KeyboardInterrupt:
